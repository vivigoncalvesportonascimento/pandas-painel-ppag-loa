# %%
import pandas as pd

# %%
df_acoes_planejamento = pd.read_csv('acoes_planejamento.csv', sep=",")

# %%
df_acoes_planejamento.head()
# Out:
#    programa_cod                    programa_desc area_tematica_cod  \
# 0             1     MINAS ÍNTEGRA E TRANSPARENTE            13AT13
# 1             1     MINAS ÍNTEGRA E TRANSPARENTE            13AT13
# 2             1     MINAS ÍNTEGRA E TRANSPARENTE            13AT13
# 3             2  AUDITORIA INTERNA PARA O FUTURO            13AT13
# 4             2  AUDITORIA INTERNA PARA O FUTURO            13AT13
#
#                                   area_tematica_desc  is_deleted_programa  \
# 0  Transparência, Combate à Corrupção, Integridad...                False
# 1  Transparência, Combate à Corrupção, Integridad...                False
# 2  Transparência, Combate à Corrupção, Integridad...                False
# 3  Transparência, Combate à Corrupção, Integridad...                False
# 4  Transparência, Combate à Corrupção, Integridad...                False
#
#    is_new_programa justificativa_is_new_programa  uo_programa_cod  \
# ...

# %%
df_acoes_planejamento.dtypes
# Out:
# programa_cod                       int64
# programa_desc                     object
# area_tematica_cod                 object
# area_tematica_desc                object
# is_deleted_programa                 bool
# is_new_programa                     bool
# justificativa_is_new_programa     object
# uo_programa_cod                    int64
# uo_programa_nome                  object
# uo_acao_cod                        int64
# uo_acao_nome                      object
# funcao_cod                         int64
# funcao_desc                       object
# subfuncao_cod                      int64
# subfuncao_desc                    object
# identificador_tipo_acao_cod        int64
# identificador_tipo_acao_desc      object
# acao_cod                           int64
# acao_desc                         object
# iag_cod                            int64
# iag_desc                          object
# projeto_estrategico_cod          float64
# projeto_estrategico               object
# ...
